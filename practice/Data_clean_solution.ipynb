# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # dealing with missing values

# %%
df = pd.read_csv('dataclean.csv')

# %%
df.isnull().sum()
# Out:
# A    0
# B    7
# C    0
# dtype: int64

# %%
df['B'].mean()
# Out:
# 59.95454545454545

# %%
df['B'].std()
# Out:
# 23.041323690330756

# %%
sb.distplot(df['B'], bins=15)

# %%
df.B.hist(bins=15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       29 non-null     int64
#  1   B       22 non-null     float64
#  2   C       29 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 824.0 bytes

# %%
sb.distplot(df.B[df.B.notnull()],bins=10)

# %%
sb.distplot(df['B'],bins=10)

# %%
df[df['B'].isnull()]
# Out:
#      A   B     C
# 2   15 NaN   293
# 5   40 NaN   893
# 10  29 NaN   629
# 16  18 NaN   365
# 22  48 NaN  1085
# 24  54 NaN  1229
# 26  69 NaN  1589

# %%
mean = df['B'].mean()
std  = df['B'].std()

s1 = pd.Series(np.random.normal(mean,std,27))

# %%
s1.head(27)
# Out:
# 0     80.711961
# 1     12.897727
# 2     46.956835
# 3     80.831782
# 4     75.772401
# 5     61.661982
# 6     88.960954
# 7     66.138715
# 8     93.078226
# 9     48.948205
# 10    58.444404
# 11    30.509976
# 12    43.607052
# 13    34.536165
# 14    48.825689
# 15    35.767654
# 16    67.181245
# 17    67.373799
# 18    73.519289
# 19    62.106726
# 20    78.365494
# 21    34.900650
# 22    69.183662
# 23    31.151140
# 24    35.175591
# 25    38.751745
# 26    10.349624
# dtype: float64

# %%
sb.distplot(s1)

# %%
df['B'].fillna(s1,inplace=True)

# %% [markdown]
# df['B']

# %%
df['B'].isnull().sum()
# Out:
# 0

# %%
sb.distplot(s1,bins=20)

# %%
sb.distplot(df.B,bins=20)

# %%
df.B.hist(bins=15)
