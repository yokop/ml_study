# %% [markdown]
# #Bias & Variance

# %%
from IPython.display import Image
Image('./bias_variance.png')

# %%
Image('./bias_variance2.png')

# %%
Image('./bias_variance3.png')

# %% [markdown]
# Good read on this subject: https://towardsdatascience.com/examples-of-bias-variance-tradeoff-in-deep-learning-6420476a20bd
