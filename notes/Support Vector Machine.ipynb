# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# Reference: https://www.jeremyjordan.me/support-vector-machines/

# %% [markdown]
# Today we'll be talking about support vector machines (SVM); this classifier works well in complicated feature domains, although requiring clear separation between classes. SVMs don't work well with noisy data, and the algorithm scales roughly cubic O(n3) to input depending on your implementation (sklearn's SVM fit time complexity is more than quadratic, so it won't be able to train quickly on large datasets (>10,000 examples).

# %% [markdown]
# Let's demonstrate how the algorithm works using an example

# %%
from IPython.display import Image
Image('1.png')

# %%
from IPython.display import Image
Image('2.png')

# %%
from IPython.display import Image
Image('3.png')

# %%
from IPython.display import Image
Image('4.png')

# %%
from IPython.display import Image
Image('5.png')

# %% [markdown]
# Support vector machine finds a descision bundry that maximizes the margins to both data sets, and tolerate at the same time individual outliers.

# %% [markdown]
# ## 2 Dimentional

# %%
from IPython.display import Image
Image('2dim.png')

# %% [markdown]
# ## Kerneling
#
# See demo: https://youtu.be/9NrALgHFwTo

# %%
from IPython.display import Image
Image('input_space.png')

# %%
from IPython.display import Image
Image('space.png')

# %% [markdown]
# The plane on multi dimentional space is called hyper-plane

# %% [markdown]
# ## GridSearchCV

# %% [markdown]
# Select the best hyper parameter for Support Vector Machines

# %% [markdown]
# See SVM code demo:
#
# https://drive.google.com/file/d/1b-T2h-kbk21Mp-eEbiYqyJatD29NqF36/view?usp=sharing
#
# See data tranformation live demo:
#
# https://drive.google.com/file/d/1EHzyb1oWo95-VGDZSNnVRl4J8ea4epuJ/view?usp=sharing
